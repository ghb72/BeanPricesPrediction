# %% [markdown]
# # LSTM model for prediction in weather and prices

# %% [markdown]
# ## Part 1: Data Analysis and new variables construction

# %%
# importing libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# Data Collection

bayo_prices = pd.read_csv('prices_data/bayo_clean_data.csv',index_col='date')
bayo_prices.index = pd.to_datetime(bayo_prices.index)

weather_zac = pd.read_csv('weather_data/zac_region_frij.csv',index_col='date')
weather_zac.index = pd.to_datetime(weather_zac.index)
weather_zac.drop(columns=['year','month'], inplace=True)

f, ax = plt.subplots(4,1, sharex=True)
for i in range(4):
    ax[i].plot(weather_zac.loc['2010-01-01':].index.values,
                weather_zac[weather_zac.columns[i]].loc['2010-01-01':].values)
    ax[i].set_ylabel(weather_zac.columns[i])

a1 = f.suptitle('Variables Climatológicas promedio: Región Frijolera Zac \n 2010 - presente')

# %%
f, ax = plt.subplots()
ax.plot(bayo_prices.index, bayo_prices.values)
ax.set_ylabel('MXN')
a2 = ax.set_title('Precio Frijol Bayo \n Central de Abastos de Zacatecas')

# %%
# to know the inital time of measures of prices of bean : 1998-01-15
bayo_prices.head()
# Out:
#             price
# date
# 1998-01-15   5.25
# 1998-02-15   5.58
# 1998-03-15   6.00
# 1998-04-15   6.00
# 1998-05-15   6.00

# %%
bayo_data = weather_zac.loc['1998-01-15':].join(bayo_prices)
print(bayo_data.info())
bayo_data.tail(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9726 entries, 1998-01-15 to 2024-09-12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rain    9725 non-null   float64
#  1   evap    9688 non-null   float64
#  2   t_max   9695 non-null   float64
#  3   t_min   9695 non-null   float64
#  4   price   278 non-null    float64
# dtypes: float64(5)
# memory usage: 455.9 KB
# None
#               rain      evap      t_max      t_min  price
# date
# 2024-08-12  0.0000  6.892500  30.400000  14.500000    NaN
# 2024-08-13  0.0000  6.317500  30.060000  14.740000    NaN
# 2024-08-14  0.3200  8.227500  29.920000  14.440000    NaN
# 2024-08-15  0.0000  6.017500  29.900000  14.740000   30.0
# 2024-08-16  0.0000  7.447500  30.600000  14.300000    NaN
# 2024-08-17  0.0000  6.667500  30.120000  14.380000    NaN
# 2024-08-18  1.9020  7.452500  29.340000  13.300000    NaN
# 2024-08-19  6.3600  8.566667  30.140000  14.840000    NaN
# 2024-08-20  0.0000  5.337500  27.425000  14.900000    NaN
# 2024-08-21  0.0025  7.330000  29.075000  13.625000    NaN
# 2024-08-22  0.0000  6.997500  30.825000  10.925000    NaN
# 2024-08-23  0.0000  7.830000  30.975000  13.925000    NaN
# 2024-08-24  0.0000  6.420000  30.433333  14.600000    NaN
# 2024-08-25  0.0000  6.986667  30.233333  12.966667    NaN
# 2024-08-26  0.0000  5.045000  29.533333  15.966667    NaN
# 2024-08-27  0.5500  6.930000  29.750000  12.700000    NaN
# 2024-08-28  0.0000  4.500000  28.100000  12.600000    NaN
# 2024-08-29  0.0000       NaN  28.000000  12.500000    NaN
# 2024-09-11  0.0000       NaN        NaN        NaN    NaN
# 2024-09-12     NaN       NaN        NaN        NaN    NaN

# %%
filled_data = bayo_data[['rain','evap','t_max','t_min']].loc[:'2024-08-15'].interpolate(method='time')
filled_data['price']  = bayo_data['price'].interpolate(method='akima')

labels_plot = ['LLuvia','Evap','Tº max','Tº min', 'Precio']

f, ax = plt.subplots(5,1, sharex=True)
for i in range(5):
    ax[i].plot(filled_data.index.values,
                filled_data[filled_data.columns[i]].values)
    ax[i].set_ylabel(labels_plot[i])

a1 = f.suptitle('Variables Climatológicas promedio: Región Frijolera Zac \n 1998 - presente')

# %% [markdown]
# Al parecer no hay datos suficientes para predecir los precios del frijol

# %%
sns.heatmap(bayo_data.corr())
# Out:
# <Axes: >

# %%
augmented_bayo_data = bayo_data.loc[:'2024-08-15']

augmented_bayo_data = augmented_bayo_data.interpolate(method='cubic')

num_cols = len(augmented_bayo_data.columns)

f, ax = plt.subplots(num_cols,1, sharex=True, figsize = (10, 10))
for i in range(num_cols):
    ax[i].plot(augmented_bayo_data.loc['2010-01-01':].index.values,
                augmented_bayo_data[augmented_bayo_data.columns[i]].loc['2010-01-01':].values)
    ax[i].set_ylabel(augmented_bayo_data.columns[i])

# %%
price_corr = augmented_bayo_data.corr()['price']
price_corr
# Out:
# rain     0.004190
# evap     0.100592
# t_max    0.199417
# t_min    0.179937
# price    1.000000
# Name: price, dtype: float64

# %%
sns.heatmap(augmented_bayo_data.corr(), center=0)
# Out:
# <Axes: >

# %% [markdown]
# ## Part 2: Data preprocessing

# %%
# to check if the date ranges are ok
fecha_inicio = augmented_bayo_data.index.min()
fecha_fin = augmented_bayo_data.index.max()
rango_completo = pd.date_range(start=fecha_inicio, end=fecha_fin, freq='D')

fechas_presentes = augmented_bayo_data.index
fechas_faltantes = rango_completo[~rango_completo.isin(fechas_presentes)]

# Cuenta las fechas faltantes
num_fechas_faltantes = len(fechas_faltantes)
print(f"Número de fechas faltantes: {num_fechas_faltantes}")

# Si deseas ver las fechas faltantes específicas:
print(f'Fecha inicio: {fecha_inicio}, fecha fin: {fecha_fin}')
print("Fechas faltantes:")
print(fechas_faltantes)
# Out:
# Número de fechas faltantes: 0
# Fecha inicio: 1998-01-15 00:00:00, fecha fin: 2024-08-15 00:00:00
# Fechas faltantes:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
split_fraction = 0.75
train_split =  int(split_fraction * int(augmented_bayo_data.shape[0]))

def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    # print('data mean:', data_mean)
    # print('data std', data_std)
    print(f'Scale factor = (data) * {data_std['price']} + {data_mean['price']}')
    return (data - data_mean) / data_std

train_split
# Out:
# 7282

# %%
features = augmented_bayo_data
# features.index = features.index.

features = normalize(features, train_split)
features = pd.DataFrame(features)

train_data = features.iloc[0: train_split -1]
test_data = features.iloc[train_split:]

features.shape
# Out:
# Scale factor = (data) * 4.6414651689814805 + 10.107023653386548
# (9710, 5)

# %%
x_train = train_data.values
y_train = train_data['price'].values

# %% [markdown]
# ## Part 3: Model Development and predictions

# %%
sequence_length = 5 # 15 days per tensor
batch_size = 120
learning_rate = 0.001

import keras
dataset_train = keras.utils.timeseries_dataset_from_array(
    data=x_train,
    targets=y_train,
    sequence_length=sequence_length,
    batch_size=batch_size,
    seed=34
)

x_test = test_data.values
y_test = test_data['price'].values

dataset_test = keras.utils.timeseries_dataset_from_array(
    data = x_test,
    targets=y_test,
    sequence_length=sequence_length,
    batch_size=batch_size,
    seed = 43
)

for batch in dataset_train.take(1):
    inputs, targets = batch

print('Input shape:',inputs.numpy().shape)
print('Target shape:', targets.numpy().shape)
# Out:
# Input shape: (120, 5, 5)
# Target shape: (120,)

# %%
inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
lstm_out = keras.layers.LSTM(32)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 5)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 32)             │         4,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,897 (19.13 KB)
#  Trainable params: 4,897 (19.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
path_checkpoint = 'model_checkpoint.weights.h5'
es_callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor='val_loss',
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True
)

###### Fitting the model
epochs = 40

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_test,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5710
# Epoch 1: val_loss improved from inf to 3.99825, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.5729 - val_loss: 3.9982
# Epoch 2/40
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1131
# Epoch 2: val_loss improved from 3.99825 to 1.49688, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1151 - val_loss: 1.4969
# Epoch 3/40
# 54/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0193
# Epoch 3: val_loss improved from 1.49688 to 0.73751, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0227 - val_loss: 0.7375
# Epoch 4/40
# 55/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0121
# Epoch 4: val_loss improved from 0.73751 to 0.56656, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0141 - val_loss: 0.5666
# Epoch 5/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0124
# Epoch 5: val_loss improved from 0.56656 to 0.46249, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0134 - val_loss: 0.4625
# Epoch 6/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125
# Epoch 6: val_loss improved from 0.46249 to 0.39574, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0132 - val_loss: 0.3957
# Epoch 7/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0123
# Epoch 7: val_loss improved from 0.39574 to 0.34958, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0128 - val_loss: 0.3496
# Epoch 8/40
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118
# Epoch 8: val_loss improved from 0.34958 to 0.31597, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0121 - val_loss: 0.3160
# Epoch 9/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0112
# Epoch 9: val_loss improved from 0.31597 to 0.28987, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0114 - val_loss: 0.2899
# Epoch 10/40
# 58/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0104
# Epoch 10: val_loss improved from 0.28987 to 0.26842, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0106 - val_loss: 0.2684
# Epoch 11/40
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096
# Epoch 11: val_loss improved from 0.26842 to 0.24996, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0097 - val_loss: 0.2500
# Epoch 12/40
# 55/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 12: val_loss improved from 0.24996 to 0.23357, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0089 - val_loss: 0.2336
# Epoch 13/40
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 13: val_loss improved from 0.23357 to 0.21870, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0081 - val_loss: 0.2187
# Epoch 14/40
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073
# Epoch 14: val_loss improved from 0.21870 to 0.20505, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0074 - val_loss: 0.2050
# Epoch 15/40
# 58/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0066
# Epoch 15: val_loss improved from 0.20505 to 0.19243, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0067 - val_loss: 0.1924
# Epoch 16/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060
# Epoch 16: val_loss improved from 0.19243 to 0.18072, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0061 - val_loss: 0.1807
# Epoch 17/40
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0055
# Epoch 17: val_loss improved from 0.18072 to 0.16981, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0055 - val_loss: 0.1698
# Epoch 18/40
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049
# Epoch 18: val_loss improved from 0.16981 to 0.15963, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0050 - val_loss: 0.1596
# Epoch 19/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0044
# Epoch 19: val_loss improved from 0.15963 to 0.15015, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0045 - val_loss: 0.1501
# Epoch 20/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040
# Epoch 20: val_loss improved from 0.15015 to 0.14132, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - val_loss: 0.1413
# Epoch 21/40
# 54/61 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035
# Epoch 21: val_loss improved from 0.14132 to 0.13313, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0036 - val_loss: 0.1331
# Epoch 22/40
# 58/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 22: val_loss improved from 0.13313 to 0.12558, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0032 - val_loss: 0.1256
# Epoch 23/40
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 23: val_loss improved from 0.12558 to 0.11866, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0029 - val_loss: 0.1187
# Epoch 24/40
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 24: val_loss improved from 0.11866 to 0.11239, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0026 - val_loss: 0.1124
# Epoch 25/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022
# Epoch 25: val_loss improved from 0.11239 to 0.10677, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023 - val_loss: 0.1068
# Epoch 26/40
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019
# Epoch 26: val_loss improved from 0.10677 to 0.10184, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0020 - val_loss: 0.1018
# Epoch 27/40
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016
# Epoch 27: val_loss improved from 0.10184 to 0.09760, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0976
# Epoch 28/40
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015
# Epoch 28: val_loss improved from 0.09760 to 0.09409, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015 - val_loss: 0.0941
# Epoch 29/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012
# Epoch 29: val_loss improved from 0.09409 to 0.09133, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 0.0913
# Epoch 30/40
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 30: val_loss improved from 0.09133 to 0.08936, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 0.0894
# Epoch 31/40
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1059e-04
# Epoch 31: val_loss improved from 0.08936 to 0.08821, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.6066e-04 - val_loss: 0.0882
# Epoch 32/40
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8338e-04
# Epoch 32: val_loss improved from 0.08821 to 0.08787, saving model to model_checkpoint.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3411e-04 - val_loss: 0.0879
# Epoch 33/40
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1810e-04
# Epoch 33: val_loss did not improve from 0.08787
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.3510e-04 - val_loss: 0.0883

# %%
def visualize_loss(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

visualize_loss(history, 'Training and Validation Loss')

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return

# %%
prediction = model.predict(dataset_test)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %%
predictions = prediction.flatten()
count_pred = len(predictions)

#(data + 10.05598903566464) * 4.654588743043078

plt.figure(figsize=(10,6))
plt.plot(test_data['price'].index, test_data['price'] * 4.578850218807721 + 10.257168845442097, label = 'Tendencia del Precio Real', lw=2)
plt.plot(test_data.iloc[:count_pred].index, predictions * 4.578850218807721 + 10.257168845442097, label = 'Tendencia predecida del Precio', lw=2)
plt.legend()
plt.text(20240*0.865,32, f'Modelo simple_1_{epochs}_{learning_rate}_{sequence_length}_{history.history['val_loss'][-1]}', fontsize=12)
t = plt.title('Tendencia Real del Precio del Frijol vs Predicha', fontsize = 18)

# %%
Val_Loss = round(history.history['val_loss'][-1], 2)
model.save(f'models/simple_1_{epochs}_{learning_rate}_{sequence_length}_{Val_Loss}.keras')
